# %% [markdown]
# <a href="https://colab.research.google.com/github/ValenteHC/Probabilidad--UNIDAD-1/blob/main/Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROBABILIDAD Y ESTADISTICA
#
# ##UNIDAD 1
#
# ###FACILITADOR: Jose Gabriel Rodrigues Rivas
#
# #### Alumno: HERRERA CARRERA VALENTIN
#
# ##### **PROGRAMA 2: MAXIMO, MINIMO Y DISPERCION DE DATOS**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
Fabrica1 = []
for _ in range(100):
  numero_aleatorio = round(random.uniform(50,1000),2)
  Fabrica1.append(numero_aleatorio)

print(Fabrica1)
# Out:
# [708.28, 742.22, 530.91, 838.92, 927.33, 116.95, 368.83, 710.2, 179.35, 622.14, 637.81, 617.59, 477.99, 776.29, 904.98, 567.26, 845.6, 926.53, 823.28, 244.44, 665.73, 739.93, 351.29, 934.09, 569.64, 243.19, 511.65, 836.02, 894.17, 77.93, 824.69, 431.04, 113.26, 92.05, 852.94, 209.36, 805.49, 941.66, 408.54, 734.27, 440.55, 864.46, 849.85, 270.27, 909.11, 910.05, 509.45, 167.08, 319.05, 104.4, 527.14, 77.34, 408.67, 933.88, 755.93, 163.62, 383.41, 569.93, 390.14, 411.31, 451.31, 419.79, 339.56, 229.42, 78.77, 943.8, 601.09, 261.9, 906.43, 165.66, 790.51, 738.41, 486.97, 268.86, 584.78, 861.4, 245.24, 278.51, 290.16, 679.28, 436.75, 65.86, 842.27, 434.04, 550.19, 863.9, 908.68, 253.14, 908.71, 91.43, 578.86, 795.07, 551.16, 380.19, 504.42, 521.79, 206.61, 576.74, 685.37, 971.34]

# %%
Fabrica2 = []
for _ in range(100):
  numero_aleatorio = round(random.uniform(50,1000),2)
  Fabrica2.append(numero_aleatorio)

print(Fabrica2)
# Out:
# [888.27, 937.84, 183.85, 653.0, 352.1, 849.2, 939.0, 394.7, 97.57, 674.01, 210.48, 258.46, 557.41, 524.89, 779.84, 478.4, 967.95, 896.37, 672.02, 477.23, 297.01, 186.09, 774.16, 801.98, 138.74, 392.12, 611.19, 160.86, 371.49, 926.87, 926.67, 851.67, 386.69, 383.71, 998.86, 112.55, 477.55, 166.49, 605.83, 177.69, 281.93, 164.63, 198.78, 72.34, 646.81, 335.5, 68.78, 495.9, 453.37, 629.85, 254.42, 278.79, 189.62, 226.72, 562.74, 657.06, 890.77, 360.57, 777.96, 99.12, 964.57, 520.13, 721.03, 673.82, 478.66, 105.05, 153.98, 230.68, 965.68, 876.85, 330.43, 816.36, 518.57, 338.29, 994.4, 885.15, 460.41, 753.51, 896.44, 913.54, 216.99, 483.99, 56.71, 165.63, 808.96, 962.4, 74.4, 951.39, 80.47, 221.94, 74.37, 342.75, 988.69, 806.31, 131.37, 416.98, 679.73, 447.0, 623.65, 633.11]

# %% [markdown]
# MAXIMO, MINIMO, RANGO

# %%
maximo1 = max(Fabrica1)
minimo1 = min(Fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(Fabrica1)
mediana1 = median(Fabrica1)
moda1 = mode(Fabrica1)
desviacion_estandar_Fabrica1 = stdev(Fabrica1)

print("Estadistica descriptiva de la Fabrica 1 \n","Media =",media1,
      "\n Medaiana =",mediana1,"\n Moda=",moda1, "\n Maximo=",maximo1,
      "\n Minimo =",minimo1,"\n Rango=", rango1)
print("Desviacion Estandar =", desviacion_estandar_Fabrica1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media = 545.1785
#  Medaiana = 550.675
#  Moda= 708.28
#  Maximo= 971.34
#  Minimo = 65.86
#  Rango= 905.48
# Desviacion Estandar = 273.9629858777653

# %%
maximo2 = max(Fabrica1)
minimo2 = min(Fabrica1)
rango2 = maximo1 - minimo1
media2 = mean(Fabrica1)
mediana2 = median(Fabrica1)
moda2 = mode(Fabrica1)
desviacion_estandar_Fabrica2 = stdev(Fabrica2)

print("Estadistica descriptiva de la Fabrica 2 \n","Media =",media2,
      "\n Medaiana =",mediana2,"\n Moda=",moda2, "\n Maximo=",maximo2,
      "\n Minimo =",minimo2,"\n Rango=", rango2)
print("Desviacion Estandar =", desviacion_estandar_Fabrica2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media = 545.1785
#  Medaiana = 550.675
#  Moda= 708.28
#  Maximo= 971.34
#  Minimo = 65.86
#  Rango= 905.48
# Desviacion Estandar = 298.0869930952467
